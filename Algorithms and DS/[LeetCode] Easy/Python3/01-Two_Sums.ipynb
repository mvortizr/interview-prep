# %% [markdown]
# ## __Two Sums__
#
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
# Example 1:
#
# ```
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Output: Because nums[0] + nums[1] == 9, we return [0, 1].
# ```
#
# Example 2:
#
# ```
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# ```
#
# Example 3:
#
# ```
# Input: nums = [3,3], target = 6
# Output: [0,1]
# ```

# %% [markdown]
# TODO: Add complexity analysis to algorithms. Time Complexity, Auxiliary Space

# %% [markdown]
# TODO: Add C/C++ solution

# %% [markdown]
# TODO: Add JavaScript solution

# %% [markdown]
# TODO: Add other solutions
# - https://www.geeksforgeeks.org/given-an-array-a-and-a-number-x-check-for-pair-in-a-with-sum-as-x/
# - https://www.geeksforgeeks.org/count-pairs-with-given-sum/

# %% [markdown]
# ### __Naive Solution__
#
# - Iterate over every selected_index,num in nums
# - Search the complement (target-num)
# - Search the indexes of the complement in nums
# - For every index of the complement return if it's not the same selected index
# - Otherwise, return an empty array

# %%
class Solution:
    
    def findIndexesCompl(self,nums,complement):
      compl_indexes = []  
      for s_index,s_val in enumerate(nums):
        if s_val == complement:
          compl_indexes.append(s_index)

      return compl_indexes

    def twoSum(self, nums: [int], target: int) -> [int]:
      for s_index,s_val in enumerate(nums):
        complement = target - s_val
        compl_indexes = self.findIndexesCompl(nums,complement)
        for i in compl_indexes:
          if s_index != i:
            return[s_index,i]
      return []
        #for i in nums:

# %% [markdown]
# ### __Hashmap + One pass__
# From this [video](https://www.youtube.com/watch?v=77OA4njtsY0)

# %%
class Solution:
    def twoSum(self, nums: [int], target: int) -> [int]:
      values = dict()
      for i, elem in enumerate(nums):
        comp = target-elem
        if comp in values:
          return[values[comp],i]
        values[elem] = i
      return []

# %% [markdown]
# ### __Test__

# %%
nums = [2,7,11,15]
target = 9
#Expected = [0,1]

# %%
nums = [3,2,4]
target = 6
#Expected = [1,2]

# %%
nums = [1,3,5,6]
target = 8
#Expected = [1,2]

# %%
nums = [4,7,2,6]
target = 12
#Expected = []

# %%
nums = [3,3]
target = 6
#Expected = [0,1]

# %%
sol = Solution()
sol.twoSum(nums,target)
# Out:
# []
