# %%
class Solution:
    def freqAlphabets(self, s: str) -> str:
        i = 0
        while i != len(str)-1:
          if s[i] == '#':
            

        print(s_list)

# %%
s = "10#11#12"

# %%
s = "1326#"

# %%
Solution().freqAlphabets(s)
# Out:
# ['1326', '']
